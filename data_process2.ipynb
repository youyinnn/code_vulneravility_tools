# %% [markdown]
# ### Print Node Frequency

# %%
import os, re

def read_out_dep_freq(data_set_name):
    with open(os.path.join('srcxml', f'{data_set_name}_out', 'de2freq.txt')) as f:
        lines = f.readlines()
        
        node_freq = {}
        
        for line in lines:
            sp = re.split('\s+', line.strip())
            freq = sp[0]
            nodes = [s for s in re.split('[-|↓|↑]', sp[1]) if s != '']

            for node in nodes:
                if node_freq.get(node) == None:
                    node_freq[node] = 0
                node_freq[node] += int(freq)
                
        node_freq_list = []
        for k, v in node_freq.items():
            node_freq_list.append((k, v))
            
        node_freq_list = sorted(node_freq_list, key=lambda a: a[1], reverse=True)
        
        return node_freq_list
                
        
read_out_dep_freq('juliet')
# Out:
# [('name', 19246),
#  ('expr', 4746),
#  ('decl', 2954),
#  ('literal', 2802),
#  ('type', 2800),
#  ('if', 1644),
#  ('try', 1552),
#  ('function', 1272),
#  ('block_content', 1204),
#  ('call', 1136),
#  ('condition', 1104),
#  ('catch', 1090),
#  ('throws', 1002),
#  ('block', 773),
#  ('init', 738),
#  ('specifier', 722),
#  ('if_stmt', 461),
#  ('operator', 392),
#  ('parameter_list', 388),
#  ('parameter', 388),
#  ('finally', 348),
#  ('argument', 238),
#  ('decl_stmt', 212),
#  ('index', 116),
#  ('for', 110),
#  ('else', 101),
#  ('return', 75),
#  ('control', 60),
#  ('expr_stmt', 20),
#  ('incr', 20)]

# %% [markdown]
# ### Get Filtered Data

# %%
def read_out_data(data_set_name):
    def read_out_de_2_id(data_set_name):
        with open(os.path.join('srcxml', f'{data_set_name}_out', 'de2id.txt')) as f:
            lines = f.readlines()
            
            id2de = {}
            
            for line in lines:
                sp = re.split('\s+', line.strip())
                id2de[int(sp[-1])] = sp[0]
                
            return id2de
        
    id2de = read_out_de_2_id('juliet')

    def read_out_voc_2_id(data_set_name):
        with open(os.path.join('srcxml', f'{data_set_name}_out', 'voc2id.txt')) as f:
            lines = f.readlines()
            
            id2voc = {}
            
            for line in lines:
                sp = re.split('\s+', line.strip())
                id2voc[int(sp[-1])] = sp[0]
                
            return id2voc

    id2voc = read_out_voc_2_id('juliet')
    
    data_list = []
    with open(os.path.join('srcxml', f'{data_set_name}_out', 'data.txt')) as f:
        lines = f.readlines()
        
        
        for line in lines:
            sp = line.strip().split(' ')
            
            num_words = int(sp[0])
            num_dep_rels = int(sp[1])
            
            token_id_list = sp[2:2+num_words]
            dep_path_list = sp[2+num_words:]
            
            decode_dep_path = []
            
            for dep_path in dep_path_list:
                srcT, desT, dep = dep_path.split('|')
                decode_dep_path.append(
                    {
                        "srcT": id2voc[int(token_id_list[int(srcT)])],
                        "desT": id2voc[int(token_id_list[int(desT)])],
                        "path": id2de[int(dep)],
                    }
                )
        
            data_list.append(
                decode_dep_path
            )
            
    return data_list
        
from tqdm import tqdm

def filter_decoded_data_list(data_set_name, removed_node_list):
    decoded_data_list = read_out_data('juliet')
    filtered_decoded_data_list = []
    for i in tqdm(range(len(decoded_data_list))):
        decoded_data = decoded_data_list[i]
        filtered_decoded_data = []
        for j in range(len(decoded_data)):
            dep_path = decoded_data[j]
            current_nodes = [s for s in re.split('[-|↓|↑]', dep_path['path']) if s != '']
            removed = False
            for node in current_nodes:
                if node in removed_node_list:
                    removed = True
                    break
                
            if removed:
                dep_path['path'] = '-***-'
                filtered_decoded_data.append(dep_path)
            else:
                filtered_decoded_data.append(dep_path)
            
        filtered_decoded_data_list.append(filtered_decoded_data)
        
    return filtered_decoded_data_list

def get_rs_obj_from_filtered_data_list(data_set_name, removed_node_list):
    
    decoded_data_list = filter_decoded_data_list(data_set_name, removed_node_list)
    
    rs_obj = dict(
        token_id_map = {},
        token_frequecy_map = {},
        dep_id_map = {
            '-***-': 0   
        },
        dep_frequecy_map = {},
        sentence_triples = [],
    )
    
    for decoded_data in decoded_data_list:
        triples = []
        for triple in decoded_data:
            srcT = triple['srcT'] 
            desT = triple['desT'] 
            dep_path = triple['path']
            
            if rs_obj['token_id_map'].get(srcT) == None:
                rs_obj['token_id_map'][srcT] = len(rs_obj['token_id_map'].keys())
                
            if rs_obj['token_frequecy_map'].get(srcT) == None:
                rs_obj['token_frequecy_map'][srcT] = 0
                
            rs_obj['token_frequecy_map'][srcT] += 1
                
            if rs_obj['token_id_map'].get(desT) == None:
                rs_obj['token_id_map'][desT] = len(rs_obj['token_id_map'].keys())
                
            if rs_obj['token_frequecy_map'].get(desT) == None:
                rs_obj['token_frequecy_map'][desT] = 0
                
            rs_obj['token_frequecy_map'][desT] += 1
            
            if rs_obj['dep_id_map'].get(dep_path) == None:
                rs_obj['dep_id_map'][dep_path] = len(rs_obj['dep_id_map'].keys())
                
            if rs_obj['dep_frequecy_map'].get(dep_path) == None:
                rs_obj['dep_frequecy_map'][dep_path] = 0
            
            rs_obj['dep_frequecy_map'][dep_path] += 1
            
            triples.append((
                rs_obj['token_id_map'][srcT],
                rs_obj['token_id_map'][desT],
                rs_obj['dep_id_map'][dep_path]
            ))
        
        rs_obj['sentence_triples'].append(triples)
    
    return rs_obj

# %%
filter_decoded_data_list('juliet', ['specifier'])
# Out:
# 100%|██████████| 118/118 [00:00<00:00, 4649.00it/s]
# [[{'srcT': 'public', 'desT': 'void', 'path': '-***-'},
#   {'srcT': 'public', 'desT': 'action', 'path': '-***-'},
#   {'srcT': 'public', 'desT': 'throws', 'path': '-***-'},
#   {'srcT': 'void', 'desT': 'public', 'path': '-***-'},
#   {'srcT': 'void', 'desT': 'action', 'path': 'name↑type↑-function-name↓'},
#   {'srcT': 'void', 'desT': 'throws', 'path': 'name↑type↑-function-throws↓'},
#   {'srcT': 'action', 'desT': 'public', 'path': '-***-'},
#   {'srcT': 'action', 'desT': 'void', 'path': 'name↑-function-type↓name↓'},
#   {'srcT': 'action', 'desT': 'throws', 'path': 'name↑-function-throws↓'},
#   {'srcT': 'string', 'desT': 'data', 'path': 'name↑type↑-decl-name↓'},
#   {'srcT': 'data', 'desT': 'string', 'path': 'name↑-decl-type↓name↓'},
#   {'srcT': 'throws', 'desT': 'public', 'path': '-***-'},
#   {'srcT': 'throws', 'desT': 'void', 'path': 'throws↑-function-type↓name↓'},
#   {'srcT': 'throws', 'desT': 'action', 'path': 'throws↑-function-name↓'},
#   {'srcT': 'throws',
#    'desT': 'throwable',
#    'path': '-throws-argument↓expr↓name↓'},
#   {'srcT': 'throwable',
#    'desT': 'throws',
#    'path': 'name↑expr↑argument↑-throws-'},
#   {'srcT': 'string', 'desT': 'root', 'path': 'name↑type↑-decl-name↓'},
#   {'srcT': 'root', 'desT': 'string', 'path': 'name↑-decl-type↓name↓'},
#   {'srcT': 'if',
#    'desT': 'tolowercase',
#    'path': '-if-condition↓expr↓call↓name↓'},
#   {'srcT': 'if', 'desT': 'indexof', 'path': '-if-condition↓expr↓call↓name↓'},
#   {'srcT': 'if', 'desT': '0', 'path': '-if-condition↓expr↓literal↓'},
#   {'srcT': 'system', 'desT': 'getproperty', 'path': 'name↑-name-name↓'},
#   {'srcT': 'system', 'desT': '0', 'path': 'name↑name↑call↑-expr-literal↓'},
#   {'srcT': 'getproperty', 'desT': 'system', 'path': 'name↑-name-name↓'},
#   {'srcT': 'getproperty',
#    'desT': '0',
#    'path': 'name↑name↑call↑-expr-literal↓'},
#   {'srcT': 'tolowercase',
#    'desT': 'if',
#    'path': 'name↑call↑expr↑condition↑-if-'},
#   {'srcT': 'tolowercase',
#    'desT': 'indexof',
#    'path': 'name↑call↑-expr-call↓name↓'},
#   {'srcT': 'tolowercase', 'desT': '0', 'path': 'name↑call↑-expr-literal↓'},
#   {'srcT': 'indexof', 'desT': 'if', 'path': 'name↑call↑expr↑condition↑-if-'},
#   {'srcT': 'indexof',
#    'desT': 'tolowercase',
#    'path': 'name↑call↑-expr-call↓name↓'},
#   {'srcT': 'indexof', 'desT': '0', 'path': 'name↑call↑-expr-literal↓'},
#   {'srcT': '0', 'desT': 'if', 'path': 'literal↑expr↑condition↑-if-'},
#   {'srcT': '0', 'desT': 'system', 'path': 'literal↑-expr-call↓name↓name↓'},
#   {'srcT': '0',
#    'desT': 'getproperty',
#    'path': 'literal↑-expr-call↓name↓name↓'},
#   {'srcT': '0', 'desT': 'tolowercase', 'path': 'literal↑-expr-call↓name↓'},
#   {'srcT': '0', 'desT': 'indexof', 'path': 'literal↑-expr-call↓name↓'},
#   {'srcT': 'root', 'desT': 'cuploads', 'path': 'name↑-expr-literal↓'},
#   {'srcT': 'cuploads', 'desT': 'root', 'path': 'literal↑-expr-name↓'},
#   {'srcT': 'else', 'desT': 'if', 'path': 'else↑-if_stmt-if↓'},
#   {'srcT': 'else',
#    'desT': 'if',
#    'path': 'else↑if_stmt↑-block_content-if_stmt↓if↓'},
#   {'srcT': 'root', 'desT': 'homeuseruploads', 'path': 'name↑-expr-literal↓'},
#   {'srcT': 'homeuseruploads', 'desT': 'root', 'path': 'literal↑-expr-name↓'},
#   {'srcT': 'if',
#    'desT': 'else',
#    'path': 'if↑if_stmt↑-block_content-if_stmt↓else↓'},
#   {'srcT': 'if', 'desT': 'data', 'path': '-if-condition↓expr↓name↓'},
#   {'srcT': 'if', 'desT': 'null', 'path': '-if-condition↓expr↓literal↓'},
#   {'srcT': 'data', 'desT': 'if', 'path': 'name↑expr↑condition↑-if-'},
#   {'srcT': 'data', 'desT': 'null', 'path': 'name↑-expr-literal↓'},
#   {'srcT': 'null', 'desT': 'if', 'path': 'literal↑expr↑condition↑-if-'},
#   {'srcT': 'null', 'desT': 'data', 'path': 'literal↑-expr-name↓'},
#   {'srcT': 'file', 'desT': 'file', 'path': 'name↑type↑-decl-name↓'},
#   {'srcT': 'file', 'desT': 'file', 'path': 'name↑-decl-type↓name↓'},
#   {'srcT': 'file', 'desT': 'new', 'path': 'name↑-decl-init↓expr↓operator↓'},
#   {'srcT': 'new', 'desT': 'file', 'path': 'operator↑expr↑init↑-decl-name↓'},
#   {'srcT': 'new', 'desT': 'file', 'path': 'operator↑-expr-call↓name↓'},
#   {'srcT': 'file', 'desT': 'new', 'path': 'name↑call↑-expr-operator↓'},
#   {'srcT': 'root', 'desT': 'data', 'path': 'name↑-expr-name↓'},
#   {'srcT': 'data', 'desT': 'root', 'path': 'name↑-expr-name↓'},
#   {'srcT': 'fileinputstream',
#    'desT': 'streamfileinputsink',
#    'path': 'name↑type↑-decl-name↓'},
#   {'srcT': 'streamfileinputsink',
#    'desT': 'fileinputstream',
#    'path': 'name↑-decl-type↓name↓'},
#   {'srcT': 'streamfileinputsink',
#    'desT': 'null',
#    'path': 'name↑-decl-init↓expr↓literal↓'},
#   {'srcT': 'null',
#    'desT': 'streamfileinputsink',
#    'path': 'literal↑expr↑init↑-decl-name↓'},
#   {'srcT': 'inputstreamreader',
#    'desT': 'readerinputstreamsink',
#    'path': 'name↑type↑-decl-name↓'},
#   {'srcT': 'readerinputstreamsink',
#    'desT': 'inputstreamreader',
#    'path': 'name↑-decl-type↓name↓'},
#   {'srcT': 'readerinputstreamsink',
#    'desT': 'null',
#    'path': 'name↑-decl-init↓expr↓literal↓'},
#   {'srcT': 'null',
#    'desT': 'readerinputstreamsink',
#    'path': 'literal↑expr↑init↑-decl-name↓'},
#   {'srcT': 'bufferedreader',
#    'desT': 'readerbufferdsink',
#    'path': 'name↑type↑-decl-name↓'},
#   {'srcT': 'readerbufferdsink',
#    'desT': 'bufferedreader',
#    'path': 'name↑-decl-type↓name↓'},
#   {'srcT': 'readerbufferdsink',
#    'desT': 'null',
#    'path': 'name↑-decl-init↓expr↓literal↓'},
#   {'srcT': 'null',
#    'desT': 'readerbufferdsink',
#    'path': 'literal↑expr↑init↑-decl-name↓'},
#   {'srcT': 'if', 'desT': 'try', 'path': '-if-block↓block_content↓try↓'},
#   {'srcT': 'file', 'desT': 'exists', 'path': 'name↑-name-name↓'},
#   {'srcT': 'exists', 'desT': 'file', 'path': 'name↑-name-name↓'},
#   {'srcT': 'file', 'desT': 'isfile', 'path': 'name↑-name-name↓'},
#   {'srcT': 'isfile', 'desT': 'file', 'path': 'name↑-name-name↓'},
#   {'srcT': 'try', 'desT': 'if', 'path': 'try↑block_content↑block↑-if-'},
#   {'srcT': 'streamfileinputsink',
#    'desT': 'new',
#    'path': 'name↑-expr-operator↓'},
#   {'srcT': 'streamfileinputsink',
#    'desT': 'fileinputstream',
#    'path': 'name↑-expr-call↓name↓'},
#   {'srcT': 'new',
#    'desT': 'streamfileinputsink',
#    'path': 'operator↑-expr-name↓'},
#   {'srcT': 'new',
#    'desT': 'fileinputstream',
#    'path': 'operator↑-expr-call↓name↓'},
#   {'srcT': 'fileinputstream',
#    'desT': 'streamfileinputsink',
#    'path': 'name↑call↑-expr-name↓'},
#   {'srcT': 'fileinputstream',
#    'desT': 'new',
#    'path': 'name↑call↑-expr-operator↓'},
#   {'srcT': 'readerinputstreamsink',
#    'desT': 'new',
#    'path': 'name↑-expr-operator↓'},
#   {'srcT': 'readerinputstreamsink',
#    'desT': 'inputstreamreader',
#    'path': 'name↑-expr-call↓name↓'},
#   {'srcT': 'new',
#    'desT': 'readerinputstreamsink',
#    'path': 'operator↑-expr-name↓'},
#   {'srcT': 'new',
#    'desT': 'inputstreamreader',
#    'path': 'operator↑-expr-call↓name↓'},
#   {'srcT': 'inputstreamreader',
#    'desT': 'readerinputstreamsink',
#    'path': 'name↑call↑-expr-name↓'},
#   {'srcT': 'inputstreamreader',
#    'desT': 'new',
#    'path': 'name↑call↑-expr-operator↓'},
#   {'srcT': 'readerbufferdsink', 'desT': 'new', 'path': 'name↑-expr-operator↓'},
#   {'srcT': 'readerbufferdsink',
#    'desT': 'bufferedreader',
#    'path': 'name↑-expr-call↓name↓'},
#   {'srcT': 'new', 'desT': 'readerbufferdsink', 'path': 'operator↑-expr-name↓'},
#   {'srcT': 'new',
#    'desT': 'bufferedreader',
#    'path': 'operator↑-expr-call↓name↓'},
#   {'srcT': 'bufferedreader',
#    'desT': 'readerbufferdsink',
#    'path': 'name↑call↑-expr-name↓'},
#   {'srcT': 'bufferedreader',
#    'desT': 'new',
#    'path': 'name↑call↑-expr-operator↓'},
#   {'srcT': 'io', 'desT': 'writeline', 'path': 'name↑-name-name↓'},
#   {'srcT': 'writeline', 'desT': 'io', 'path': 'name↑-name-name↓'},
#   {'srcT': 'readerbufferdsink',
#    'desT': 'readline',
#    'path': 'name↑-name-name↓'},
#   {'srcT': 'readline',
#    'desT': 'readerbufferdsink',
#    'path': 'name↑-name-name↓'},
#   {'srcT': 'catch',
#    'desT': 'exceptio',
#    'path': '-catch-parameter_list↓parameter↓decl↓name↓'},
#   {'srcT': 'catch', 'desT': 'finally', 'path': 'catch↑-try-finally↓'},
#   {'srcT': 'ioexception', 'desT': 'exceptio', 'path': 'name↑type↑-decl-name↓'},
#   {'srcT': 'exceptio',
#    'desT': 'catch',
#    'path': 'name↑decl↑parameter↑parameter_list↑-catch-'},
#   {'srcT': 'exceptio', 'desT': 'ioexception', 'path': 'name↑-decl-type↓name↓'},
#   {'srcT': 'io', 'desT': 'logger', 'path': 'name↑-name-name↓'},
#   {'srcT': 'io', 'desT': 'log', 'path': 'name↑-name-name↓'},
#   {'srcT': 'logger', 'desT': 'io', 'path': 'name↑-name-name↓'},
#   {'srcT': 'logger', 'desT': 'log', 'path': 'name↑-name-name↓'},
#   {'srcT': 'log', 'desT': 'io', 'path': 'name↑-name-name↓'},
#   {'srcT': 'log', 'desT': 'logger', 'path': 'name↑-name-name↓'},
#   {'srcT': 'level', 'desT': 'warning', 'path': 'name↑-name-name↓'},
#   {'srcT': 'warning', 'desT': 'level', 'path': 'name↑-name-name↓'},
#   {'srcT': 'finally', 'desT': 'catch', 'path': 'finally↑-try-catch↓'},
#   {'srcT': 'finally',
#    'desT': 'try',
#    'path': '-finally-block↓block_content↓try↓'},
#   {'srcT': 'finally',
#    'desT': 'catch',
#    'path': '-finally-block↓block_content↓try↓catch↓'},
#   {'srcT': 'try',
#    'desT': 'finally',
#    'path': 'try↑block_content↑block↑-finally-'},
#   {'srcT': 'try',
#    'desT': 'if',
#    'path': '-try-block↓block_content↓if_stmt↓if↓'},
#   {'srcT': 'try', 'desT': 'catch', 'path': '-try-catch↓'},
#   {'srcT': 'if',
#    'desT': 'try',
#    'path': 'if↑if_stmt↑block_content↑block↑-try-'},
#   {'srcT': 'if',
#    'desT': 'readerbufferdsink',
#    'path': '-if-condition↓expr↓name↓'},
#   {'srcT': 'if', 'desT': 'null', 'path': '-if-condition↓expr↓literal↓'},
#   {'srcT': 'readerbufferdsink',
#    'desT': 'if',
#    'path': 'name↑expr↑condition↑-if-'},
#   {'srcT': 'readerbufferdsink', 'desT': 'null', 'path': 'name↑-expr-literal↓'},
#   {'srcT': 'null', 'desT': 'if', 'path': 'literal↑expr↑condition↑-if-'},
#   {'srcT': 'null', 'desT': 'readerbufferdsink', 'path': 'literal↑-expr-name↓'},
#   {'srcT': 'readerbufferdsink', 'desT': 'close', 'path': 'name↑-name-name↓'},
#   {'srcT': 'close', 'desT': 'readerbufferdsink', 'path': 'name↑-name-name↓'},
#   {'srcT': 'catch',
#    'desT': 'finally',
#    'path': 'catch↑try↑block_content↑block↑-finally-'},
#   {'srcT': 'catch', 'desT': 'try', 'path': 'catch↑-try-'},
#   {'srcT': 'catch',
#    'desT': 'exceptio',
#    'path': '-catch-parameter_list↓parameter↓decl↓name↓'},
#   {'srcT': 'catch', 'desT': 'try', 'path': 'catch↑try↑-block_content-try↓'},
#   {'srcT': 'ioexception', 'desT': 'exceptio', 'path': 'name↑type↑-decl-name↓'},
#   {'srcT': 'exceptio',
#    'desT': 'catch',
#    'path': 'name↑decl↑parameter↑parameter_list↑-catch-'},
#   {'srcT': 'exceptio', 'desT': 'ioexception', 'path': 'name↑-decl-type↓name↓'},
#   {'srcT': 'io', 'desT': 'logger', 'path': 'name↑-name-name↓'},
#   {'srcT': 'io', 'desT': 'log', 'path': 'name↑-name-name↓'},
#   {'srcT': 'logger', 'desT': 'io', 'path': 'name↑-name-name↓'},
#   {'srcT': 'logger', 'desT': 'log', 'path': 'name↑-name-name↓'},
#   {'srcT': 'log', 'desT': 'io', 'path': 'name↑-name-name↓'},
#   {'srcT': 'log', 'desT': 'logger', 'path': 'name↑-name-name↓'},
#   {'srcT': 'level', 'desT': 'warning', 'path': 'name↑-name-name↓'},
#   {'srcT': 'warning', 'desT': 'level', 'path': 'name↑-name-name↓'},
#   {'srcT': 'try', 'desT': 'catch', 'path': 'try↑-block_content-try↓catch↓'},
#   {'srcT': 'try',
#    'desT': 'if',
#    'path': '-try-block↓block_content↓if_stmt↓if↓'},
#   {'srcT': 'try', 'desT': 'catch', 'path': '-try-catch↓'},
#   {'srcT': 'if',
#    'desT': 'try',
#    'path': 'if↑if_stmt↑block_content↑block↑-try-'},
#   {'srcT': 'if',
#    'desT': 'readerinputstreamsink',
#    'path': '-if-condition↓expr↓name↓'},
#   {'srcT': 'if', 'desT': 'null', 'path': '-if-condition↓expr↓literal↓'},
#   {'srcT': 'readerinputstreamsink',
#    'desT': 'if',
#    'path': 'name↑expr↑condition↑-if-'},
#   {'srcT': 'readerinputstreamsink',
#    'desT': 'null',
#    'path': 'name↑-expr-literal↓'},
#   {'srcT': 'null', 'desT': 'if', 'path': 'literal↑expr↑condition↑-if-'},
#   {'srcT': 'null',
#    'desT': 'readerinputstreamsink',
#    'path': 'literal↑-expr-name↓'},
#   {'srcT': 'readerinputstreamsink',
#    'desT': 'close',
#    'path': 'name↑-name-name↓'},
#   {'srcT': 'close',
#    'desT': 'readerinputstreamsink',
#    'path': 'name↑-name-name↓'},
#   {'srcT': 'catch', 'desT': 'try', 'path': 'catch↑-try-'},
#   {'srcT': 'catch',
#    'desT': 'exceptio',
#    'path': '-catch-parameter_list↓parameter↓decl↓name↓'},
#   {'srcT': 'catch', 'desT': 'try', 'path': 'catch↑try↑-block_content-try↓'},
#   {'srcT': 'ioexception', 'desT': 'exceptio', 'path': 'name↑type↑-decl-name↓'},
#   {'srcT': 'exceptio',
#    'desT': 'catch',
#    'path': 'name↑decl↑parameter↑parameter_list↑-catch-'},
#   {'srcT': 'exceptio', 'desT': 'ioexception', 'path': 'name↑-decl-type↓name↓'},
#   {'srcT': 'io', 'desT': 'logger', 'path': 'name↑-name-name↓'},
#   {'srcT': 'io', 'desT': 'log', 'path': 'name↑-name-name↓'},
#   {'srcT': 'logger', 'desT': 'io', 'path': 'name↑-name-name↓'},
#   {'srcT': 'logger', 'desT': 'log', 'path': 'name↑-name-name↓'},
#   {'srcT': 'log', 'desT': 'io', 'path': 'name↑-name-name↓'},
#   {'srcT': 'log', 'desT': 'logger', 'path': 'name↑-name-name↓'},
#   {'srcT': 'level', 'desT': 'warning', 'path': 'name↑-name-name↓'},
#   {'srcT': 'warning', 'desT': 'level', 'path': 'name↑-name-name↓'},
#   {'srcT': 'try', 'desT': 'catch', 'path': 'try↑-block_content-try↓catch↓'},
#   {'srcT': 'try',
#    'desT': 'if',
#    'path': '-try-block↓block_content↓if_stmt↓if↓'},
#   {'srcT': 'try', 'desT': 'catch', 'path': '-try-catch↓'},
#   {'srcT': 'if',
#    'desT': 'try',
#    'path': 'if↑if_stmt↑block_content↑block↑-try-'},
#   {'srcT': 'if',
#    'desT': 'streamfileinputsink',
#    'path': '-if-condition↓expr↓name↓'},
#   {'srcT': 'if', 'desT': 'null', 'path': '-if-condition↓expr↓literal↓'},
#   {'srcT': 'streamfileinputsink',
#    'desT': 'if',
#    'path': 'name↑expr↑condition↑-if-'},
#   {'srcT': 'streamfileinputsink',
#    'desT': 'null',
#    'path': 'name↑-expr-literal↓'},
#   {'srcT': 'null', 'desT': 'if', 'path': 'literal↑expr↑condition↑-if-'},
#   {'srcT': 'null',
#    'desT': 'streamfileinputsink',
#    'path': 'literal↑-expr-name↓'},
#   {'srcT': 'streamfileinputsink', 'desT': 'close', 'path': 'name↑-name-name↓'},
#   {'srcT': 'close', 'desT': 'streamfileinputsink', 'path': 'name↑-name-name↓'},
#   {'srcT': 'catch', 'desT': 'try', 'path': 'catch↑-try-'},
#   {'srcT': 'catch',
#    'desT': 'exceptio',
#    'path': '-catch-parameter_list↓parameter↓decl↓name↓'},
#   {'srcT': 'ioexception', 'desT': 'exceptio', 'path': 'name↑type↑-decl-name↓'},
#   {'srcT': 'exceptio',
#    'desT': 'catch',
#    'path': 'name↑decl↑parameter↑parameter_list↑-catch-'},
#   {'srcT': 'exceptio', 'desT': 'ioexception', 'path': 'name↑-decl-type↓name↓'},
#   {'srcT': 'io', 'desT': 'logger', 'path': 'name↑-name-name↓'},
#   {'srcT': 'io', 'desT': 'log', 'path': 'name↑-name-name↓'},
#   {'srcT': 'logger', 'desT': 'io', 'path': 'name↑-name-name↓'},
#   {'srcT': 'logger', 'desT': 'log', 'path': 'name↑-name-name↓'},
#   {'srcT': 'log', 'desT': 'io', 'path': 'name↑-name-name↓'},
#   {'srcT': 'log', 'desT': 'logger', 'path': 'name↑-name-name↓'},
#   {'srcT': 'level', 'desT': 'warning', 'path': 'name↑-name-name↓'},
#   {'srcT': 'warning', 'desT': 'level', 'path': 'name↑-name-name↓'}],
#  [{'srcT': 'public', 'desT': 'void', 'path': '-***-'},
#   {'srcT': 'public', 'desT': 'action', 'path': '-***-'},
#   {'srcT': 'public', 'desT': 'throws', 'path': '-***-'},
#   {'srcT': 'void', 'desT': 'public', 'path': '-***-'},
#   {'srcT': 'void', 'desT': 'action', 'path': 'name↑type↑-function-name↓'},
#   {'srcT': 'void', 'desT': 'throws', 'path': 'name↑type↑-function-throws↓'},
#   {'srcT': 'action', 'desT': 'public', 'path': '-***-'},
#   {'srcT': 'action', 'desT': 'void', 'path': 'name↑-function-type↓name↓'},
#   {'srcT': 'action', 'desT': 'throws', 'path': 'name↑-function-throws↓'},
#   {'srcT': 'string', 'desT': 'data', 'path': 'name↑type↑-decl-name↓'},
#   {'srcT': 'data', 'desT': 'string', 'path': 'name↑-decl-type↓name↓'},
#   {'srcT': 'throws', 'desT': 'public', 'path': '-***-'},
#   {'srcT': 'throws', 'desT': 'void', 'path': 'throws↑-function-type↓name↓'},
#   {'srcT': 'throws', 'desT': 'action', 'path': 'throws↑-function-name↓'},
#   {'srcT': 'throws',
#    'desT': 'throwable',
#    'path': '-throws-argument↓expr↓name↓'},
#   {'srcT': 'throwable',
#    'desT': 'throws',
#    'path': 'name↑expr↑argument↑-throws-'},
#   {'srcT': 'if', 'desT': 'data', 'path': '-if-condition↓expr↓name↓'},
#   {'srcT': 'if', 'desT': 'null', 'path': '-if-condition↓expr↓literal↓'},
#   {'srcT': 'data', 'desT': 'if', 'path': 'name↑expr↑condition↑-if-'},
#   {'srcT': 'data', 'desT': 'null', 'path': 'name↑-expr-literal↓'},
#   {'srcT': 'null', 'desT': 'if', 'path': 'literal↑expr↑condition↑-if-'},
#   {'srcT': 'null', 'desT': 'data', 'path': 'literal↑-expr-name↓'},
#   {'srcT': 'file', 'desT': 'file', 'path': 'name↑type↑-decl-name↓'},
#   {'srcT': 'file', 'desT': 'file', 'path': 'name↑-decl-type↓name↓'},
#   {'srcT': 'file', 'desT': 'new', 'path': 'name↑-decl-init↓expr↓operator↓'},
#   {'srcT': 'new', 'desT': 'file', 'path': 'operator↑expr↑init↑-decl-name↓'},
#   {'srcT': 'new', 'desT': 'file', 'path': 'operator↑-expr-call↓name↓'},
#   {'srcT': 'file', 'desT': 'new', 'path': 'name↑call↑-expr-operator↓'},
#   {'srcT': 'fileinputstream',
#    'desT': 'streamfileinputsink',
#    'path': 'name↑type↑-decl-name↓'},
#   {'srcT': 'streamfileinputsink',
#    'desT': 'fileinputstream',
#    'path': 'name↑-decl-type↓name↓'},
#   {'srcT': 'streamfileinputsink',
#    'desT': 'null',
#    'path': 'name↑-decl-init↓expr↓literal↓'},
#   {'srcT': 'null',
#    'desT': 'streamfileinputsink',
#    'path': 'literal↑expr↑init↑-decl-name↓'},
#   {'srcT': 'inputstreamreader',
#    'desT': 'readerinputstreamsink',
#    'path': 'name↑type↑-decl-name↓'},
#   {'srcT': 'readerinputstreamsink',
#    'desT': 'inputstreamreader',
#    'path': 'name↑-decl-type↓name↓'},
#   {'srcT': 'readerinputstreamsink',
#    'desT': 'null',
#    'path': 'name↑-decl-init↓expr↓literal↓'},
#   {'srcT': 'null',
#    'desT': 'readerinputstreamsink',
#    'path': 'literal↑expr↑init↑-decl-name↓'},
#   {'srcT': 'bufferedreader',
#    'desT': 'readerbufferdsink',
#    'path': 'name↑type↑-decl-name↓'},
#   {'srcT': 'readerbufferdsink',
#    'desT': 'bufferedreader',
#    'path': 'name↑-decl-type↓name↓'},
#   {'srcT': 'readerbufferdsink',
#    'desT': 'null',
#    'path': 'name↑-decl-init↓expr↓literal↓'},
#   {'srcT': 'null',
#    'desT': 'readerbufferdsink',
#    'path': 'literal↑expr↑init↑-decl-name↓'},
#   {'srcT': 'if', 'desT': 'try', 'path': '-if-block↓block_content↓try↓'},
#   {'srcT': 'file', 'desT': 'exists', 'path': 'name↑-name-name↓'},
#   {'srcT': 'exists', 'desT': 'file', 'path': 'name↑-name-name↓'},
#   {'srcT': 'file', 'desT': 'isfile', 'path': 'name↑-name-name↓'},
#   {'srcT': 'isfile', 'desT': 'file', 'path': 'name↑-name-name↓'},
#   {'srcT': 'try', 'desT': 'if', 'path': 'try↑block_content↑block↑-if-'},
#   {'srcT': 'streamfileinputsink',
#    'desT': 'new',
#    'path': 'name↑-expr-operator↓'},
#   {'srcT': 'streamfileinputsink',
#    'desT': 'fileinputstream',
#    'path': 'name↑-expr-call↓name↓'},
#   {'srcT': 'new',
#    'desT': 'streamfileinputsink',
#    'path': 'operator↑-expr-name↓'},
#   {'srcT': 'new',
#    'desT': 'fileinputstream',
#    'path': 'operator↑-expr-call↓name↓'},
#   {'srcT': 'fileinputstream',
#    'desT': 'streamfileinputsink',
#    'path': 'name↑call↑-expr-name↓'},
#   {'srcT': 'fileinputstream',
#    'desT': 'new',
#    'path': 'name↑call↑-expr-operator↓'},
#   {'srcT': 'readerinputstreamsink',
#    'desT': 'new',
#    'path': 'name↑-expr-operator↓'},
#   {'srcT': 'readerinputstreamsink',
#    'desT': 'inputstreamreader',
#    'path': 'name↑-expr-call↓name↓'},
#   {'srcT': 'new',
#    'desT': 'readerinputstreamsink',
#    'path': 'operator↑-expr-name↓'},
#   {'srcT': 'new',
#    'desT': 'inputstreamreader',
#    'path': 'operator↑-expr-call↓name↓'},
#   {'srcT': 'inputstreamreader',
#    'desT': 'readerinputstreamsink',
#    'path': 'name↑call↑-expr-name↓'},
#   {'srcT': 'inputstreamreader',
#    'desT': 'new',
#    'path': 'name↑call↑-expr-operator↓'},
#   {'srcT': 'readerbufferdsink', 'desT': 'new', 'path': 'name↑-expr-operator↓'},
#   {'srcT': 'readerbufferdsink',
#    'desT': 'bufferedreader',
#    'path': 'name↑-expr-call↓name↓'},
#   {'srcT': 'new', 'desT': 'readerbufferdsink', 'path': 'operator↑-expr-name↓'},
#   {'srcT': 'new',
#    'desT': 'bufferedreader',
#    'path': 'operator↑-expr-call↓name↓'},
#   {'srcT': 'bufferedreader',
#    'desT': 'readerbufferdsink',
#    'path': 'name↑call↑-expr-name↓'},
#   {'srcT': 'bufferedreader',
#    'desT': 'new',
#    'path': 'name↑call↑-expr-operator↓'},
#   {'srcT': 'io', 'desT': 'writeline', 'path': 'name↑-name-name↓'},
#   {'srcT': 'writeline', 'desT': 'io', 'path': 'name↑-name-name↓'},
#   {'srcT': 'readerbufferdsink',
#    'desT': 'readline',
#    'path': 'name↑-name-name↓'},
#   {'srcT': 'readline',
#    'desT': 'readerbufferdsink',
#    'path': 'name↑-name-name↓'},
#   {'srcT': 'catch',
#    'desT': 'exceptio',
#    'path': '-catch-parameter_list↓parameter↓decl↓name↓'},
#   {'srcT': 'catch', 'desT': 'finally', 'path': 'catch↑-try-finally↓'},
#   {'srcT': 'ioexception', 'desT': 'exceptio', 'path': 'name↑type↑-decl-name↓'},
#   {'srcT': 'exceptio',
#    'desT': 'catch',
#    'path': 'name↑decl↑parameter↑parameter_list↑-catch-'},
#   {'srcT': 'exceptio', 'desT': 'ioexception', 'path': 'name↑-decl-type↓name↓'},
#   {'srcT': 'io', 'desT': 'logger', 'path': 'name↑-name-name↓'},
#   {'srcT': 'io', 'desT': 'log', 'path': 'name↑-name-name↓'},
#   {'srcT': 'logger', 'desT': 'io', 'path': 'name↑-name-name↓'},
#   {'srcT': 'logger', 'desT': 'log', 'path': 'name↑-name-name↓'},
#   {'srcT': 'log', 'desT': 'io', 'path': 'name↑-name-name↓'},
#   {'srcT': 'log', 'desT': 'logger', 'path': 'name↑-name-name↓'},
#   {'srcT': 'level', 'desT': 'warning', 'path': 'name↑-name-name↓'},
#   {'srcT': 'warning', 'desT': 'level', 'path': 'name↑-name-name↓'},
#   {'srcT': 'finally', 'desT': 'catch', 'path': 'finally↑-try-catch↓'},
#   {'srcT': 'finally',
#    'desT': 'try',
#    'path': '-finally-block↓block_content↓try↓'},
#   {'srcT': 'finally',
#    'desT': 'catch',
#    'path': '-finally-block↓block_content↓try↓catch↓'},
#   {'srcT': 'try',
#    'desT': 'finally',
#    'path': 'try↑block_content↑block↑-finally-'},
#   {'srcT': 'try',
#    'desT': 'if',
#    'path': '-try-block↓block_content↓if_stmt↓if↓'},
#   {'srcT': 'try', 'desT': 'catch', 'path': '-try-catch↓'},
#   {'srcT': 'if',
#    'desT': 'try',
#    'path': 'if↑if_stmt↑block_content↑block↑-try-'},
#   {'srcT': 'if',
#    'desT': 'readerbufferdsink',
#    'path': '-if-condition↓expr↓name↓'},
#   {'srcT': 'if', 'desT': 'null', 'path': '-if-condition↓expr↓literal↓'},
#   {'srcT': 'readerbufferdsink',
#    'desT': 'if',
#    'path': 'name↑expr↑condition↑-if-'},
#   {'srcT': 'readerbufferdsink', 'desT': 'null', 'path': 'name↑-expr-literal↓'},
#   {'srcT': 'null', 'desT': 'if', 'path': 'literal↑expr↑condition↑-if-'},
#   {'srcT': 'null', 'desT': 'readerbufferdsink', 'path': 'literal↑-expr-name↓'},
#   {'srcT': 'readerbufferdsink', 'desT': 'close', 'path': 'name↑-name-name↓'},
#   {'srcT': 'close', 'desT': 'readerbufferdsink', 'path': 'name↑-name-name↓'},
#   {'srcT': 'catch',
#    'desT': 'finally',
#    'path': 'catch↑try↑block_content↑block↑-finally-'},
#   {'srcT': 'catch', 'desT': 'try', 'path': 'catch↑-try-'},
#   {'srcT': 'catch',
#    'desT': 'exceptio',
#    'path': '-catch-parameter_list↓parameter↓decl↓name↓'},
#   {'srcT': 'catch', 'desT': 'try', 'path': 'catch↑try↑-block_content-try↓'},
#   {'srcT': 'ioexception', 'desT': 'exceptio', 'path': 'name↑type↑-decl-name↓'},
#   {'srcT': 'exceptio',
#    'desT': 'catch',
#    'path': 'name↑decl↑parameter↑parameter_list↑-catch-'},
#   {'srcT': 'exceptio', 'desT': 'ioexception', 'path': 'name↑-decl-type↓name↓'},
#   {'srcT': 'io', 'desT': 'logger', 'path': 'name↑-name-name↓'},
#   {'srcT': 'io', 'desT': 'log', 'path': 'name↑-name-name↓'},
#   {'srcT': 'logger', 'desT': 'io', 'path': 'name↑-name-name↓'},
#   {'srcT': 'logger', 'desT': 'log', 'path': 'name↑-name-name↓'},
#   {'srcT': 'log', 'desT': 'io', 'path': 'name↑-name-name↓'},
#   {'srcT': 'log', 'desT': 'logger', 'path': 'name↑-name-name↓'},
#   {'srcT': 'level', 'desT': 'warning', 'path': 'name↑-name-name↓'},
#   {'srcT': 'warning', 'desT': 'level', 'path': 'name↑-name-name↓'},
#   {'srcT': 'try', 'desT': 'catch', 'path': 'try↑-block_content-try↓catch↓'},
#   {'srcT': 'try',
#    'desT': 'if',
#    'path': '-try-block↓block_content↓if_stmt↓if↓'},
#   {'srcT': 'try', 'desT': 'catch', 'path': '-try-catch↓'},
#   {'srcT': 'if',
#    'desT': 'try',
#    'path': 'if↑if_stmt↑block_content↑block↑-try-'},
#   {'srcT': 'if',
#    'desT': 'readerinputstreamsink',
#    'path': '-if-condition↓expr↓name↓'},
#   {'srcT': 'if', 'desT': 'null', 'path': '-if-condition↓expr↓literal↓'},
#   {'srcT': 'readerinputstreamsink',
#    'desT': 'if',
#    'path': 'name↑expr↑condition↑-if-'},
#   {'srcT': 'readerinputstreamsink',
#    'desT': 'null',
#    'path': 'name↑-expr-literal↓'},
#   {'srcT': 'null', 'desT': 'if', 'path': 'literal↑expr↑condition↑-if-'},
#   {'srcT': 'null',
#    'desT': 'readerinputstreamsink',
#    'path': 'literal↑-expr-name↓'},
#   {'srcT': 'readerinputstreamsink',
#    'desT': 'close',
#    'path': 'name↑-name-name↓'},
#   {'srcT': 'close',
#    'desT': 'readerinputstreamsink',
#    'path': 'name↑-name-name↓'},
#   {'srcT': 'catch', 'desT': 'try', 'path': 'catch↑-try-'},
#   {'srcT': 'catch',
#    'desT': 'exceptio',
#    'path': '-catch-parameter_list↓parameter↓decl↓name↓'},
#   {'srcT': 'catch', 'desT': 'try', 'path': 'catch↑try↑-block_content-try↓'},
#   {'srcT': 'ioexception', 'desT': 'exceptio', 'path': 'name↑type↑-decl-name↓'},
#   {'srcT': 'exceptio',
#    'desT': 'catch',
#    'path': 'name↑decl↑parameter↑parameter_list↑-catch-'},
#   {'srcT': 'exceptio', 'desT': 'ioexception', 'path': 'name↑-decl-type↓name↓'},
#   {'srcT': 'io', 'desT': 'logger', 'path': 'name↑-name-name↓'},
#   {'srcT': 'io', 'desT': 'log', 'path': 'name↑-name-name↓'},
#   {'srcT': 'logger', 'desT': 'io', 'path': 'name↑-name-name↓'},
#   {'srcT': 'logger', 'desT': 'log', 'path': 'name↑-name-name↓'},
#   {'srcT': 'log', 'desT': 'io', 'path': 'name↑-name-name↓'},
#   {'srcT': 'log', 'desT': 'logger', 'path': 'name↑-name-name↓'},
#   {'srcT': 'level', 'desT': 'warning', 'path': 'name↑-name-name↓'},
#   {'srcT': 'warning', 'desT': 'level', 'path': 'name↑-name-name↓'},
#   {'srcT': 'try', 'desT': 'catch', 'path': 'try↑-block_content-try↓catch↓'},
#   {'srcT': 'try',
#    'desT': 'if',
#    'path': '-try-block↓block_content↓if_stmt↓if↓'},
#   {'srcT': 'try', 'desT': 'catch', 'path': '-try-catch↓'},
#   {'srcT': 'if',
#    'desT': 'try',
#    'path': 'if↑if_stmt↑block_content↑block↑-try-'},
#   {'srcT': 'if',
#    'desT': 'streamfileinputsink',
#    'path': '-if-condition↓expr↓name↓'},
#   {'srcT': 'if', 'desT': 'null', 'path': '-if-condition↓expr↓literal↓'},
#   {'srcT': 'streamfileinputsink',
#    'desT': 'if',
#    'path': 'name↑expr↑condition↑-if-'},
#   {'srcT': 'streamfileinputsink',
#    'desT': 'null',
#    'path': 'name↑-expr-literal↓'},
#   {'srcT': 'null', 'desT': 'if', 'path': 'literal↑expr↑condition↑-if-'},
#   {'srcT': 'null',
#    'desT': 'streamfileinputsink',
#    'path': 'literal↑-expr-name↓'},
#   {'srcT': 'streamfileinputsink', 'desT': 'close', 'path': 'name↑-name-name↓'},
#   {'srcT': 'close', 'desT': 'streamfileinputsink', 'path': 'name↑-name-name↓'},
#   {'srcT': 'catch', 'desT': 'try', 'path': 'catch↑-try-'},
#   {'srcT': 'catch',
#    'desT': 'exceptio',
#    'path': '-catch-parameter_list↓parameter↓decl↓name↓'},
#   {'srcT': 'ioexception', 'desT': 'exceptio', 'path': 'name↑type↑-decl-name↓'},
#   {'srcT': 'exceptio',
#    'desT': 'catch',
#    'path': 'name↑decl↑parameter↑parameter_list↑-catch-'},
#   {'srcT': 'exceptio', 'desT': 'ioexception', 'path': 'name↑-decl-type↓name↓'},
#   {'srcT': 'io', 'desT': 'logger', 'path': 'name↑-name-name↓'},
#   {'srcT': 'io', 'desT': 'log', 'path': 'name↑-name-name↓'},
#   {'srcT': 'logger', 'desT': 'io', 'path': 'name↑-name-name↓'},
#   {'srcT': 'logger', 'desT': 'log', 'path': 'name↑-name-name↓'},
#   {'srcT': 'log', 'desT': 'io', 'path': 'name↑-name-name↓'},
#   {'srcT': 'log', 'desT': 'logger', 'path': 'name↑-name-name↓'},
#   {'srcT': 'level', 'desT': 'warning', 'path': 'name↑-name-name↓'},
#   {'srcT': 'warning', 'desT': 'level', 'path': 'name↑-name-name↓'}],
#  [{'srcT': 'public', 'desT': 'void', 'path': '-***-'},
#   {'srcT': 'public', 'desT': 'action', 'path': '-***-'},
#   {'srcT': 'public', 'desT': 'throws', 'path': '-***-'},
#   {'srcT': 'void', 'desT': 'public', 'path': '-***-'},
#   {'srcT': 'void', 'desT': 'action', 'path': 'name↑type↑-function-name↓'},
#   {'srcT': 'void', 'desT': 'throws', 'path': 'name↑type↑-function-throws↓'},
#   {'srcT': 'action', 'desT': 'public', 'path': '-***-'},
#   {'srcT': 'action', 'desT': 'void', 'path': 'name↑-function-type↓name↓'},
#   {'srcT': 'action', 'desT': 'throws', 'path': 'name↑-function-throws↓'},
#   {'srcT': 'string', 'desT': 'data', 'path': 'name↑type↑-decl-name↓'},
#   {'srcT': 'data', 'desT': 'string', 'path': 'name↑-decl-type↓name↓'},
#   {'srcT': 'throws', 'desT': 'public', 'path': '-***-'},
#   {'srcT': 'throws', 'desT': 'void', 'path': 'throws↑-function-type↓name↓'},
#   {'srcT': 'throws', 'desT': 'action', 'path': 'throws↑-function-name↓'},
#   {'srcT': 'throws',
#    'desT': 'throwable',
#    'path': '-throws-argument↓expr↓name↓'},
#   {'srcT': 'throwable',
#    'desT': 'throws',
#    'path': 'name↑expr↑argument↑-throws-'},
#   {'srcT': 'if', 'desT': 'data', 'path': '-if-condition↓expr↓name↓'},
#   {'srcT': 'if', 'desT': 'null', 'path': '-if-condition↓expr↓literal↓'},
#   {'srcT': 'data', 'desT': 'if', 'path': 'name↑expr↑condition↑-if-'},
#   {'srcT': 'data', 'desT': 'null', 'path': 'name↑-expr-literal↓'},
#   {'srcT': 'null', 'desT': 'if', 'path': 'literal↑expr↑condition↑-if-'},
#   {'srcT': 'null', 'desT': 'data', 'path': 'literal↑-expr-name↓'},
#   {'srcT': 'file', 'desT': 'file', 'path': 'name↑type↑-decl-name↓'},
#   {'srcT': 'file', 'desT': 'file', 'path': 'name↑-decl-type↓name↓'},
#   {'srcT': 'file', 'desT': 'new', 'path': 'name↑-decl-init↓expr↓operator↓'},
#   {'srcT': 'new', 'desT': 'file', 'path': 'operator↑expr↑init↑-decl-name↓'},
#   {'srcT': 'new', 'desT': 'file', 'path': 'operator↑-expr-call↓name↓'},
#   {'srcT': 'file', 'desT': 'new', 'path': 'name↑call↑-expr-operator↓'},
#   {'srcT': 'fileinputstream',
#    'desT': 'streamfileinputsink',
#    'path': 'name↑type↑-decl-name↓'},
#   {'srcT': 'streamfileinputsink',
#    'desT': 'fileinputstream',
#    'path': 'name↑-decl-type↓name↓'},
#   {'srcT': 'streamfileinputsink',
#    'desT': 'null',
#    'path': 'name↑-decl-init↓expr↓literal↓'},
#   {'srcT': 'null',
#    'desT': 'streamfileinputsink',
#    'path': 'literal↑expr↑init↑-decl-name↓'},
#   {'srcT': 'inputstreamreader',
#    'desT': 'readerinputstreamsink',
#    'path': 'name↑type↑-decl-name↓'},
#   {'srcT': 'readerinputstreamsink',
#    'desT': 'inputstreamreader',
#    'path': 'name↑-decl-type↓name↓'},
#   {'srcT': 'readerinputstreamsink',
#    'desT': 'null',
#    'path': 'name↑-decl-init↓expr↓literal↓'},
#   {'srcT': 'null',
#    'desT': 'readerinputstreamsink',
#    'path': 'literal↑expr↑init↑-decl-name↓'},
#   {'srcT': 'bufferedreader',
#    'desT': 'readerbufferdsink',
#    'path': 'name↑type↑-decl-name↓'},
#   {'srcT': 'readerbufferdsink',
#    'desT': 'bufferedreader',
#    'path': 'name↑-decl-type↓name↓'},
#   {'srcT': 'readerbufferdsink',
#    'desT': 'null',
#    'path': 'name↑-decl-init↓expr↓literal↓'},
#   {'srcT': 'null',
#    'desT': 'readerbufferdsink',
#    'path': 'literal↑expr↑init↑-decl-name↓'},
#   {'srcT': 'if', 'desT': 'try', 'path': '-if-block↓block_content↓try↓'},
#   {'srcT': 'file', 'desT': 'exists', 'path': 'name↑-name-name↓'},
#   {'srcT': 'exists', 'desT': 'file', 'path': 'name↑-name-name↓'},
#   {'srcT': 'file', 'desT': 'isfile', 'path': 'name↑-name-name↓'},
#   {'srcT': 'isfile', 'desT': 'file', 'path': 'name↑-name-name↓'},
#   {'srcT': 'try', 'desT': 'if', 'path': 'try↑block_content↑block↑-if-'},
#   {'srcT': 'streamfileinputsink',
#    'desT': 'new',
#    'path': 'name↑-expr-operator↓'},
#   {'srcT': 'streamfileinputsink',
#    'desT': 'fileinputstream',
#    'path': 'name↑-expr-call↓name↓'},
#   {'srcT': 'new',
#    'desT': 'streamfileinputsink',
#    'path': 'operator↑-expr-name↓'},
#   {'srcT': 'new',
#    'desT': 'fileinputstream',
#    'path': 'operator↑-expr-call↓name↓'},
#   {'srcT': 'fileinputstream',
#    'desT': 'streamfileinputsink',
#    'path': 'name↑call↑-expr-name↓'},
#   {'srcT': 'fileinputstream',
#    'desT': 'new',
#    'path': 'name↑call↑-expr-operator↓'},
#   {'srcT': 'readerinputstreamsink',
#    'desT': 'new',
#    'path': 'name↑-expr-operator↓'},
#   {'srcT': 'readerinputstreamsink',
#    'desT': 'inputstreamreader',
#    'path': 'name↑-expr-call↓name↓'},
#   {'srcT': 'new',
#    'desT': 'readerinputstreamsink',
#    'path': 'operator↑-expr-name↓'},
#   {'srcT': 'new',
#    'desT': 'inputstreamreader',
#    'path': 'operator↑-expr-call↓name↓'},
#   {'srcT': 'inputstreamreader',
#    'desT': 'readerinputstreamsink',
#    'path': 'name↑call↑-expr-name↓'},
#   {'srcT': 'inputstreamreader',
#    'desT': 'new',
#    'path': 'name↑call↑-expr-operator↓'},
#   {'srcT': 'readerbufferdsink', 'desT': 'new', 'path': 'name↑-expr-operator↓'},
#   {'srcT': 'readerbufferdsink',
#    'desT': 'bufferedreader',
#    'path': 'name↑-expr-call↓name↓'},
#   {'srcT': 'new', 'desT': 'readerbufferdsink', 'path': 'operator↑-expr-name↓'},
#   {'srcT': 'new',
#    'desT': 'bufferedreader',
#    'path': 'operator↑-expr-call↓name↓'},
#   {'srcT': 'bufferedreader',
#    'desT': 'readerbufferdsink',
#    'path': 'name↑call↑-expr-name↓'},
#   {'srcT': 'bufferedreader',
#    'desT': 'new',
#    'path': 'name↑call↑-expr-operator↓'},
#   {'srcT': 'io', 'desT': 'writeline', 'path': 'name↑-name-name↓'},
#   {'srcT': 'writeline', 'desT': 'io', 'path': 'name↑-name-name↓'},
#   {'srcT': 'readerbufferdsink',
#    'desT': 'readline',
#    'path': 'name↑-name-name↓'},
#   {'srcT': 'readline',
#    'desT': 'readerbufferdsink',
#    'path': 'name↑-name-name↓'},
#   {'srcT': 'catch',
#    'desT': 'exceptio',
#    'path': '-catch-parameter_list↓parameter↓decl↓name↓'},
#   {'srcT': 'catch', 'desT': 'finally', 'path': 'catch↑-try-finally↓'},
#   {'srcT': 'ioexception', 'desT': 'exceptio', 'path': 'name↑type↑-decl-name↓'},
#   {'srcT': 'exceptio',
#    'desT': 'catch',
#    'path': 'name↑decl↑parameter↑parameter_list↑-catch-'},
#   {'srcT': 'exceptio', 'desT': 'ioexception', 'path': 'name↑-decl-type↓name↓'},
#   {'srcT': 'io', 'desT': 'logger', 'path': 'name↑-name-name↓'},
#   {'srcT': 'io', 'desT': 'log', 'path': 'name↑-name-name↓'},
#   {'srcT': 'logger', 'desT': 'io', 'path': 'name↑-name-name↓'},
#   {'srcT': 'logger', 'desT': 'log', 'path': 'name↑-name-name↓'},
#   {'srcT': 'log', 'desT': 'io', 'path': 'name↑-name-name↓'},
#   {'srcT': 'log', 'desT': 'logger', 'path': 'name↑-name-name↓'},
#   {'srcT': 'level', 'desT': 'warning', 'path': 'name↑-name-name↓'},
#   {'srcT': 'warning', 'desT': 'level', 'path': 'name↑-name-name↓'},
#   {'srcT': 'finally', 'desT': 'catch', 'path': 'finally↑-try-catch↓'},
#   {'srcT': 'finally',
#    'desT': 'try',
#    'path': '-finally-block↓block_content↓try↓'},
#   {'srcT': 'finally',
#    'desT': 'catch',
#    'path': '-finally-block↓block_content↓try↓catch↓'},
#   {'srcT': 'try',
#    'desT': 'finally',
#    'path': 'try↑block_content↑block↑-finally-'},
#   {'srcT': 'try',
#    'desT': 'if',
#    'path': '-try-block↓block_content↓if_stmt↓if↓'},
#   {'srcT': 'try', 'desT': 'catch', 'path': '-try-catch↓'},
#   {'srcT': 'if',
#    'desT': 'try',
#    'path': 'if↑if_stmt↑block_content↑block↑-try-'},
#   {'srcT': 'if',
#    'desT': 'readerbufferdsink',
#    'path': '-if-condition↓expr↓name↓'},
#   {'srcT': 'if', 'desT': 'null', 'path': '-if-condition↓expr↓literal↓'},
#   {'srcT': 'readerbufferdsink',
#    'desT': 'if',
#    'path': 'name↑expr↑condition↑-if-'},
#   {'srcT': 'readerbufferdsink', 'desT': 'null', 'path': 'name↑-expr-literal↓'},
#   {'srcT': 'null', 'desT': 'if', 'path': 'literal↑expr↑condition↑-if-'},
#   {'srcT': 'null', 'desT': 'readerbufferdsink', 'path': 'literal↑-expr-name↓'},
#   {'srcT': 'readerbufferdsink', 'desT': 'close', 'path': 'name↑-name-name↓'},
#   {'srcT': 'close', 'desT': 'readerbufferdsink', 'path': 'name↑-name-name↓'},
#   {'srcT': 'catch',
#    'desT': 'finally',
#    'path': 'catch↑try↑block_content↑block↑-finally-'},
#   {'srcT': 'catch', 'desT': 'try', 'path': 'catch↑-try-'},
#   {'srcT': 'catch',
#    'desT': 'exceptio',
#    'path': '-catch-parameter_list↓parameter↓decl↓name↓'},
#   {'srcT': 'catch', 'desT': 'try', 'path': 'catch↑try↑-block_content-try↓'},
#   {'srcT': 'ioexception', 'desT': 'exceptio', 'path': 'name↑type↑-decl-name↓'},
#   {'srcT': 'exceptio',
#    'desT': 'catch',
#    'path': 'name↑decl↑parameter↑parameter_list↑-catch-'},
#   {'srcT': 'exceptio', 'desT': 'ioexception', 'path': 'name↑-decl-type↓name↓'},
#   {'srcT': 'io', 'desT': 'logger', 'path': 'name↑-name-name↓'},
#   {'srcT': 'io', 'desT': 'log', 'path': 'name↑-name-name↓'},
#   {'srcT': 'logger', 'desT': 'io', 'path': 'name↑-name-name↓'},
#   {'srcT': 'logger', 'desT': 'log', 'path': 'name↑-name-name↓'},
#   {'srcT': 'log', 'desT': 'io', 'path': 'name↑-name-name↓'},
#   {'srcT': 'log', 'desT': 'logger', 'path': 'name↑-name-name↓'},
#   {'srcT': 'level', 'desT': 'warning', 'path': 'name↑-name-name↓'},
#   {'srcT': 'warning', 'desT': 'level', 'path': 'name↑-name-name↓'},
#   {'srcT': 'try', 'desT': 'catch', 'path': 'try↑-block_content-try↓catch↓'},
#   {'srcT': 'try',
#    'desT': 'if',
#    'path': '-try-block↓block_content↓if_stmt↓if↓'},
#   {'srcT': 'try', 'desT': 'catch', 'path': '-try-catch↓'},
#   {'srcT': 'if',
#    'desT': 'try',
#    'path': 'if↑if_stmt↑block_content↑block↑-try-'},
#   {'srcT': 'if',
#    'desT': 'readerinputstreamsink',
#    'path': '-if-condition↓expr↓name↓'},
#   {'srcT': 'if', 'desT': 'null', 'path': '-if-condition↓expr↓literal↓'},
#   {'srcT': 'readerinputstreamsink',
#    'desT': 'if',
#    'path': 'name↑expr↑condition↑-if-'},
#   {'srcT': 'readerinputstreamsink',
#    'desT': 'null',
#    'path': 'name↑-expr-literal↓'},
#   {'srcT': 'null', 'desT': 'if', 'path': 'literal↑expr↑condition↑-if-'},
#   {'srcT': 'null',
#    'desT': 'readerinputstreamsink',
#    'path': 'literal↑-expr-name↓'},
#   {'srcT': 'readerinputstreamsink',
#    'desT': 'close',
#    'path': 'name↑-name-name↓'},
#   {'srcT': 'close',
#    'desT': 'readerinputstreamsink',
#    'path': 'name↑-name-name↓'},
#   {'srcT': 'catch', 'desT': 'try', 'path': 'catch↑-try-'},
#   {'srcT': 'catch',
#    'desT': 'exceptio',
#    'path': '-catch-parameter_list↓parameter↓decl↓name↓'},
#   {'srcT': 'catch', 'desT': 'try', 'path': 'catch↑try↑-block_content-try↓'},
#   {'srcT': 'ioexception', 'desT': 'exceptio', 'path': 'name↑type↑-decl-name↓'},
#   {'srcT': 'exceptio',
#    'desT': 'catch',
#    'path': 'name↑decl↑parameter↑parameter_list↑-catch-'},
#   {'srcT': 'exceptio', 'desT': 'ioexception', 'path': 'name↑-decl-type↓name↓'},
#   {'srcT': 'io', 'desT': 'logger', 'path': 'name↑-name-name↓'},
#   {'srcT': 'io', 'desT': 'log', 'path': 'name↑-name-name↓'},
#   {'srcT': 'logger', 'desT': 'io', 'path': 'name↑-name-name↓'},
#   {'srcT': 'logger', 'desT': 'log', 'path': 'name↑-name-name↓'},
#   {'srcT': 'log', 'desT': 'io', 'path': 'name↑-name-name↓'},
#   {'srcT': 'log', 'desT': 'logger', 'path': 'name↑-name-name↓'},
#   {'srcT': 'level', 'desT': 'warning', 'path': 'name↑-name-name↓'},
#   {'srcT': 'warning', 'desT': 'level', 'path': 'name↑-name-name↓'},
#   {'srcT': 'try', 'desT': 'catch', 'path': 'try↑-block_content-try↓catch↓'},
#   {'srcT': 'try',
#    'desT': 'if',
#    'path': '-try-block↓block_content↓if_stmt↓if↓'},
#   {'srcT': 'try', 'desT': 'catch', 'path': '-try-catch↓'},
#   {'srcT': 'if',
#    'desT': 'try',
#    'path': 'if↑if_stmt↑block_content↑block↑-try-'},
#   {'srcT': 'if',
#    'desT': 'streamfileinputsink',
#    'path': '-if-condition↓expr↓name↓'},
#   {'srcT': 'if', 'desT': 'null', 'path': '-if-condition↓expr↓literal↓'},
#   {'srcT': 'streamfileinputsink',
#    'desT': 'if',
#    'path': 'name↑expr↑condition↑-if-'},
#   {'srcT': 'streamfileinputsink',
#    'desT': 'null',
#    'path': 'name↑-expr-literal↓'},
#   {'srcT': 'null', 'desT': 'if', 'path': 'literal↑expr↑condition↑-if-'},
#   {'srcT': 'null',
#    'desT': 'streamfileinputsink',
#    'path': 'literal↑-expr-name↓'},
#   {'srcT': 'streamfileinputsink', 'desT': 'close', 'path': 'name↑-name-name↓'},
#   {'srcT': 'close', 'desT': 'streamfileinputsink', 'path': 'name↑-name-name↓'},
#   {'srcT': 'catch', 'desT': 'try', 'path': 'catch↑-try-'},
#   {'srcT': 'catch',
#    'desT': 'exceptio',
#    'path': '-catch-parameter_list↓parameter↓decl↓name↓'},
#   {'srcT': 'ioexception', 'desT': 'exceptio', 'path': 'name↑type↑-decl-name↓'},
#   {'srcT': 'exceptio',
#    'desT': 'catch',
#    'path': 'name↑decl↑parameter↑parameter_list↑-catch-'},
#   {'srcT': 'exceptio', 'desT': 'ioexception', 'path': 'name↑-decl-type↓name↓'},
#   {'srcT': 'io', 'desT': 'logger', 'path': 'name↑-name-name↓'},
#   {'srcT': 'io', 'desT': 'log', 'path': 'name↑-name-name↓'},
#   {'srcT': 'logger', 'desT': 'io', 'path': 'name↑-name-name↓'},
#   {'srcT': 'logger', 'desT': 'log', 'path': 'name↑-name-name↓'},
#   {'srcT': 'log', 'desT': 'io', 'path': 'name↑-name-name↓'},
#   {'srcT': 'log', 'desT': 'logger', 'path': 'name↑-name-name↓'},
#   {'srcT': 'level', 'desT': 'warning', 'path': 'name↑-name-name↓'},
#   {'srcT': 'warning', 'desT': 'level', 'path': 'name↑-name-name↓'}],
#  [{'srcT': 'public', 'desT': 'void', 'path': '-***-'},
#   {'srcT': 'public', 'desT': 'action', 'path': '-***-'},
#   {'srcT': 'public', 'desT': 'throws', 'path': '-***-'},
#   {'srcT': 'void', 'desT': 'public', 'path': '-***-'},
#   {'srcT': 'void', 'desT': 'action', 'path': 'name↑type↑-function-name↓'},
#   {'srcT': 'void', 'desT': 'throws', 'path': 'name↑type↑-function-throws↓'},
#   {'srcT': 'action', 'desT': 'public', 'path': '-***-'},
#   {'srcT': 'action', 'desT': 'void', 'path': 'name↑-function-type↓name↓'},
#   {'srcT': 'action', 'desT': 'throws', 'path': 'name↑-function-throws↓'},
#   {'srcT': 'string', 'desT': 'data', 'path': 'name↑type↑-decl-name↓'},
#   {'srcT': 'data', 'desT': 'string', 'path': 'name↑-decl-type↓name↓'},
#   {'srcT': 'throws', 'desT': 'public', 'path': '-***-'},
#   {'srcT': 'throws', 'desT': 'void', 'path': 'throws↑-function-type↓name↓'},
#   {'srcT': 'throws', 'desT': 'action', 'path': 'throws↑-function-name↓'},
#   {'srcT': 'throws',
#    'desT': 'throwable',
#    'path': '-throws-argument↓expr↓name↓'},
#   {'srcT': 'throwable',
#    'desT': 'throws',
#    'path': 'name↑expr↑argument↑-throws-'},
#   {'srcT': 'if', 'desT': 'data', 'path': '-if-condition↓expr↓name↓'},
#   {'srcT': 'if', 'desT': 'null', 'path': '-if-condition↓expr↓literal↓'},
#   {'srcT': 'data', 'desT': 'if', 'path': 'name↑expr↑condition↑-if-'},
#   {'srcT': 'data', 'desT': 'null', 'path': 'name↑-expr-literal↓'},
#   {'srcT': 'null', 'desT': 'if', 'path': 'literal↑expr↑condition↑-if-'},
#   {'srcT': 'null', 'desT': 'data', 'path': 'literal↑-expr-name↓'},
#   {'srcT': 'file', 'desT': 'file', 'path': 'name↑type↑-decl-name↓'},
#   {'srcT': 'file', 'desT': 'file', 'path': 'name↑-decl-type↓name↓'},
#   {'srcT': 'file', 'desT': 'new', 'path': 'name↑-decl-init↓expr↓operator↓'},
#   {'srcT': 'new', 'desT': 'file', 'path': 'operator↑expr↑init↑-decl-name↓'},
#   {'srcT': 'new', 'desT': 'file', 'path': 'operator↑-expr-call↓name↓'},
#   {'srcT': 'file', 'desT': 'new', 'path': 'name↑call↑-expr-operator↓'},
#   {'srcT': 'fileinputstream',
#    'desT': 'streamfileinputsink',
#    'path': 'name↑type↑-decl-name↓'},
#   {'srcT': 'streamfileinputsink',
#    'desT': 'fileinputstream',
#    'path': 'name↑-decl-type↓name↓'},
#   {'srcT': 'streamfileinputsink',
#    'desT': 'null',
#    'path': 'name↑-decl-init↓expr↓literal↓'},
#   {'srcT': 'null',
#    'desT': 'streamfileinputsink',
#    'path': 'literal↑expr↑init↑-decl-name↓'},
#   {'srcT': 'inputstreamreader',
#    'desT': 'readerinputstreamsink',
#    'path': 'name↑type↑-decl-name↓'},
#   {'srcT': 'readerinputstreamsink',
#    'desT': 'inputstreamreader',
#    'path': 'name↑-decl-type↓name↓'},
#   {'srcT': 'readerinputstreamsink',
#    'desT': 'null',
#    'path': 'name↑-decl-init↓expr↓literal↓'},
#   {'srcT': 'null',
#    'desT': 'readerinputstreamsink',
#    'path': 'literal↑expr↑init↑-decl-name↓'},
#   {'srcT': 'bufferedreader',
#    'desT': 'readerbufferdsink',
#    'path': 'name↑type↑-decl-name↓'},
#   {'srcT': 'readerbufferdsink',
#    'desT': 'bufferedreader',
#    'path': 'name↑-decl-type↓name↓'},
#   {'srcT': 'readerbufferdsink',
#    'desT': 'null',
#    'path': 'name↑-decl-init↓expr↓literal↓'},
#   {'srcT': 'null',
#    'desT': 'readerbufferdsink',
#    'path': 'literal↑expr↑init↑-decl-name↓'},
#   {'srcT': 'if', 'desT': 'try', 'path': '-if-block↓block_content↓try↓'},
#   {'srcT': 'file', 'desT': 'exists', 'path': 'name↑-name-name↓'},
#   {'srcT': 'exists', 'desT': 'file', 'path': 'name↑-name-name↓'},
#   {'srcT': 'file', 'desT': 'isfile', 'path': 'name↑-name-name↓'},
#   {'srcT': 'isfile', 'desT': 'file', 'path': 'name↑-name-name↓'},
#   {'srcT': 'try', 'desT': 'if', 'path': 'try↑block_content↑block↑-if-'},
#   {'srcT': 'streamfileinputsink',
#    'desT': 'new',
#    'path': 'name↑-expr-operator↓'},
#   {'srcT': 'streamfileinputsink',
#    'desT': 'fileinputstream',
#    'path': 'name↑-expr-call↓name↓'},
#   {'srcT': 'new',
#    'desT': 'streamfileinputsink',
#    'path': 'operator↑-expr-name↓'},
#   {'srcT': 'new',
#    'desT': 'fileinputstream',
#    'path': 'operator↑-expr-call↓name↓'},
#   {'srcT': 'fileinputstream',
#    'desT': 'streamfileinputsink',
#    'path': 'name↑call↑-expr-name↓'},
#   {'srcT': 'fileinputstream',
#    'desT': 'new',
#    'path': 'name↑call↑-expr-operator↓'},
#   {'srcT': 'readerinputstreamsink',
#    'desT': 'new',
#    'path': 'name↑-expr-operator↓'},
#   {'srcT': 'readerinputstreamsink',
#    'desT': 'inputstreamreader',
#    'path': 'name↑-expr-call↓name↓'},
#   {'srcT': 'new',
#    'desT': 'readerinputstreamsink',
#    'path': 'operator↑-expr-name↓'},
#   {'srcT': 'new',
#    'desT': 'inputstreamreader',
#    'path': 'operator↑-expr-call↓name↓'},
#   {'srcT': 'inputstreamreader',
#    'desT': 'readerinputstreamsink',
#    'path': 'name↑call↑-expr-name↓'},
#   {'srcT': 'inputstreamreader',
#    'desT': 'new',
#    'path': 'name↑call↑-expr-operator↓'},
#   {'srcT': 'readerbufferdsink', 'desT': 'new', 'path': 'name↑-expr-operator↓'},
#   {'srcT': 'readerbufferdsink',
#    'desT': 'bufferedreader',
#    'path': 'name↑-expr-call↓name↓'},
#   {'srcT': 'new', 'desT': 'readerbufferdsink', 'path': 'operator↑-expr-name↓'},
#   {'srcT': 'new',
#    'desT': 'bufferedreader',
#    'path': 'operator↑-expr-call↓name↓'},
#   {'srcT': 'bufferedreader',
#    'desT': 'readerbufferdsink',
#    'path': 'name↑call↑-expr-name↓'},
#   {'srcT': 'bufferedreader',
#    'desT': 'new',
#    'path': 'name↑call↑-expr-operator↓'},
#   {'srcT': 'io', 'desT': 'writeline', 'path': 'name↑-name-name↓'},
#   {'srcT': 'writeline', 'desT': 'io', 'path': 'name↑-name-name↓'},
#   {'srcT': 'readerbufferdsink',
#    'desT': 'readline',
#    'path': 'name↑-name-name↓'},
#   {'srcT': 'readline',
#    'desT': 'readerbufferdsink',
#    'path': 'name↑-name-name↓'},
#   {'srcT': 'catch',
#    'desT': 'exceptio',
#    'path': '-catch-parameter_list↓parameter↓decl↓name↓'},
#   {'srcT': 'catch', 'desT': 'finally', 'path': 'catch↑-try-finally↓'},
#   {'srcT': 'ioexception', 'desT': 'exceptio', 'path': 'name↑type↑-decl-name↓'},
#   {'srcT': 'exceptio',
#    'desT': 'catch',
#    'path': 'name↑decl↑parameter↑parameter_list↑-catch-'},
#   {'srcT': 'exceptio', 'desT': 'ioexception', 'path': 'name↑-decl-type↓name↓'},
#   {'srcT': 'io', 'desT': 'logger', 'path': 'name↑-name-name↓'},
#   {'srcT': 'io', 'desT': 'log', 'path': 'name↑-name-name↓'},
#   {'srcT': 'logger', 'desT': 'io', 'path': 'name↑-name-name↓'},
#   {'srcT': 'logger', 'desT': 'log', 'path': 'name↑-name-name↓'},
#   {'srcT': 'log', 'desT': 'io', 'path': 'name↑-name-name↓'},
#   {'srcT': 'log', 'desT': 'logger', 'path': 'name↑-name-name↓'},
#   {'srcT': 'level', 'desT': 'warning', 'path': 'name↑-name-name↓'},
#   {'srcT': 'warning', 'desT': 'level', 'path': 'name↑-name-name↓'},
#   {'srcT': 'finally', 'desT': 'catch', 'path': 'finally↑-try-catch↓'},
#   {'srcT': 'finally',
#    'desT': 'try',
#    'path': '-finally-block↓block_content↓try↓'},
#   {'srcT': 'finally',
#    'desT': 'catch',
#    'path': '-finally-block↓block_content↓try↓catch↓'},
#   {'srcT': 'try',
#    'desT': 'finally',
#    'path': 'try↑block_content↑block↑-finally-'},
#   {'srcT': 'try',
#    'desT': 'if',
#    'path': '-try-block↓block_content↓if_stmt↓if↓'},
#   {'srcT': 'try', 'desT': 'catch', 'path': '-try-catch↓'},
#   {'srcT': 'if',
#    'desT': 'try',
#    'path': 'if↑if_stmt↑block_content↑block↑-try-'},
#   {'srcT': 'if',
#    'desT': 'readerbufferdsink',
#    'path': '-if-condition↓expr↓name↓'},
#   {'srcT': 'if', 'desT': 'null', 'path': '-if-condition↓expr↓literal↓'},
#   {'srcT': 'readerbufferdsink',
#    'desT': 'if',
#    'path': 'name↑expr↑condition↑-if-'},
#   {'srcT': 'readerbufferdsink', 'desT': 'null', 'path': 'name↑-expr-literal↓'},
#   {'srcT': 'null', 'desT': 'if', 'path': 'literal↑expr↑condition↑-if-'},
# ...
#   {'srcT': 'null', 'desT': 'if', 'path': 'literal↑expr↑condition↑-if-'},
#   {'srcT': 'null', 'desT': 'sqlstatement', 'path': 'literal↑-expr-name↓'},
#   {'srcT': 'sqlstatement', 'desT': 'close', 'path': 'name↑-name-name↓'},
#   {'srcT': 'close', 'desT': 'sqlstatement', 'path': 'name↑-name-name↓'},
#   {'srcT': 'catch', 'desT': 'try', 'path': 'catch↑-try-'},
#   {'srcT': 'catch',
#    'desT': 'exceptsql',
#    'path': '-catch-parameter_list↓parameter↓decl↓name↓'},
#   {'srcT': 'catch', 'desT': 'try', 'path': 'catch↑try↑-block_content-try↓'},
#   {'srcT': 'sqlexception',
#    'desT': 'exceptsql',
#    'path': 'name↑type↑-decl-name↓'},
#   {'srcT': 'exceptsql',
#    'desT': 'catch',
#    'path': 'name↑decl↑parameter↑parameter_list↑-catch-'},
#   {'srcT': 'exceptsql',
#    'desT': 'sqlexception',
#    'path': 'name↑-decl-type↓name↓'},
#   {'srcT': 'io', 'desT': 'logger', 'path': 'name↑-name-name↓'},
#   {'srcT': 'io', 'desT': 'log', 'path': 'name↑-name-name↓'},
#   {'srcT': 'logger', 'desT': 'io', 'path': 'name↑-name-name↓'},
#   {'srcT': 'logger', 'desT': 'log', 'path': 'name↑-name-name↓'},
#   {'srcT': 'log', 'desT': 'io', 'path': 'name↑-name-name↓'},
#   {'srcT': 'log', 'desT': 'logger', 'path': 'name↑-name-name↓'},
#   {'srcT': 'level', 'desT': 'warning', 'path': 'name↑-name-name↓'},
#   {'srcT': 'warning', 'desT': 'level', 'path': 'name↑-name-name↓'},
#   {'srcT': 'try', 'desT': 'catch', 'path': 'try↑-block_content-try↓catch↓'},
#   {'srcT': 'try',
#    'desT': 'if',
#    'path': '-try-block↓block_content↓if_stmt↓if↓'},
#   {'srcT': 'try', 'desT': 'catch', 'path': '-try-catch↓'},
#   {'srcT': 'if',
#    'desT': 'try',
#    'path': 'if↑if_stmt↑block_content↑block↑-try-'},
#   {'srcT': 'if', 'desT': 'dbconnection', 'path': '-if-condition↓expr↓name↓'},
#   {'srcT': 'if', 'desT': 'null', 'path': '-if-condition↓expr↓literal↓'},
#   {'srcT': 'dbconnection', 'desT': 'if', 'path': 'name↑expr↑condition↑-if-'},
#   {'srcT': 'dbconnection', 'desT': 'null', 'path': 'name↑-expr-literal↓'},
#   {'srcT': 'null', 'desT': 'if', 'path': 'literal↑expr↑condition↑-if-'},
#   {'srcT': 'null', 'desT': 'dbconnection', 'path': 'literal↑-expr-name↓'},
#   {'srcT': 'dbconnection', 'desT': 'close', 'path': 'name↑-name-name↓'},
#   {'srcT': 'close', 'desT': 'dbconnection', 'path': 'name↑-name-name↓'},
#   {'srcT': 'catch', 'desT': 'try', 'path': 'catch↑-try-'},
#   {'srcT': 'catch',
#    'desT': 'exceptsql',
#    'path': '-catch-parameter_list↓parameter↓decl↓name↓'},
#   {'srcT': 'sqlexception',
#    'desT': 'exceptsql',
#    'path': 'name↑type↑-decl-name↓'},
#   {'srcT': 'exceptsql',
#    'desT': 'catch',
#    'path': 'name↑decl↑parameter↑parameter_list↑-catch-'},
#   {'srcT': 'exceptsql',
#    'desT': 'sqlexception',
#    'path': 'name↑-decl-type↓name↓'},
#   {'srcT': 'io', 'desT': 'logger', 'path': 'name↑-name-name↓'},
#   {'srcT': 'io', 'desT': 'log', 'path': 'name↑-name-name↓'},
#   {'srcT': 'logger', 'desT': 'io', 'path': 'name↑-name-name↓'},
#   {'srcT': 'logger', 'desT': 'log', 'path': 'name↑-name-name↓'},
#   {'srcT': 'log', 'desT': 'io', 'path': 'name↑-name-name↓'},
#   {'srcT': 'log', 'desT': 'logger', 'path': 'name↑-name-name↓'},
#   {'srcT': 'level', 'desT': 'warning', 'path': 'name↑-name-name↓'},
#   {'srcT': 'warning', 'desT': 'level', 'path': 'name↑-name-name↓'}],
#  [{'srcT': 'public', 'desT': 'void', 'path': '-***-'},
#   {'srcT': 'public', 'desT': 'action', 'path': '-***-'},
#   {'srcT': 'public', 'desT': 'throws', 'path': '-***-'},
#   {'srcT': 'void', 'desT': 'public', 'path': '-***-'},
#   {'srcT': 'void', 'desT': 'action', 'path': 'name↑type↑-function-name↓'},
#   {'srcT': 'void', 'desT': 'throws', 'path': 'name↑type↑-function-throws↓'},
#   {'srcT': 'action', 'desT': 'public', 'path': '-***-'},
#   {'srcT': 'action', 'desT': 'void', 'path': 'name↑-function-type↓name↓'},
#   {'srcT': 'action', 'desT': 'throws', 'path': 'name↑-function-throws↓'},
#   {'srcT': 'string', 'desT': 'data', 'path': 'name↑type↑-decl-name↓'},
#   {'srcT': 'data', 'desT': 'string', 'path': 'name↑-decl-type↓name↓'},
#   {'srcT': 'throws', 'desT': 'public', 'path': '-***-'},
#   {'srcT': 'throws', 'desT': 'void', 'path': 'throws↑-function-type↓name↓'},
#   {'srcT': 'throws', 'desT': 'action', 'path': 'throws↑-function-name↓'},
#   {'srcT': 'throws',
#    'desT': 'throwable',
#    'path': '-throws-argument↓expr↓name↓'},
#   {'srcT': 'throws',
#    'desT': 'try',
#    'path': 'throws↑-function-block↓block_content↓try↓'},
#   {'srcT': 'throwable',
#    'desT': 'throws',
#    'path': 'name↑expr↑argument↑-throws-'},
#   {'srcT': 'connection',
#    'desT': 'dbconnection',
#    'path': 'name↑type↑-decl-name↓'},
#   {'srcT': 'dbconnection',
#    'desT': 'connection',
#    'path': 'name↑-decl-type↓name↓'},
#   {'srcT': 'dbconnection',
#    'desT': 'null',
#    'path': 'name↑-decl-init↓expr↓literal↓'},
#   {'srcT': 'dbconnection',
#    'desT': 'try',
#    'path': 'name↑decl↑decl_stmt↑-block_content-try↓'},
#   {'srcT': 'null',
#    'desT': 'dbconnection',
#    'path': 'literal↑expr↑init↑-decl-name↓'},
#   {'srcT': 'statement',
#    'desT': 'sqlstatement',
#    'path': 'name↑type↑-decl-name↓'},
#   {'srcT': 'sqlstatement',
#    'desT': 'statement',
#    'path': 'name↑-decl-type↓name↓'},
#   {'srcT': 'sqlstatement',
#    'desT': 'null',
#    'path': 'name↑-decl-init↓expr↓literal↓'},
#   {'srcT': 'sqlstatement',
#    'desT': 'try',
#    'path': 'name↑decl↑decl_stmt↑-block_content-try↓'},
#   {'srcT': 'null',
#    'desT': 'sqlstatement',
#    'path': 'literal↑expr↑init↑-decl-name↓'},
#   {'srcT': 'try',
#    'desT': 'action',
#    'path': 'try↑block_content↑block↑-function-name↓'},
#   {'srcT': 'try',
#    'desT': 'throws',
#    'path': 'try↑block_content↑block↑-function-throws↓'},
#   {'srcT': 'try',
#    'desT': 'dbconnection',
#    'path': 'try↑-block_content-decl_stmt↓decl↓name↓'},
#   {'srcT': 'try',
#    'desT': 'sqlstatement',
#    'path': 'try↑-block_content-decl_stmt↓decl↓name↓'},
#   {'srcT': 'dbconnection', 'desT': 'io', 'path': 'name↑-expr-call↓name↓name↓'},
#   {'srcT': 'dbconnection',
#    'desT': 'getdbconnection',
#    'path': 'name↑-expr-call↓name↓name↓'},
#   {'srcT': 'io', 'desT': 'dbconnection', 'path': 'name↑name↑call↑-expr-name↓'},
#   {'srcT': 'io', 'desT': 'getdbconnection', 'path': 'name↑-name-name↓'},
#   {'srcT': 'getdbconnection',
#    'desT': 'dbconnection',
#    'path': 'name↑name↑call↑-expr-name↓'},
#   {'srcT': 'getdbconnection', 'desT': 'io', 'path': 'name↑-name-name↓'},
#   {'srcT': 'sqlstatement',
#    'desT': 'dbconnection',
#    'path': 'name↑-expr-call↓name↓name↓'},
#   {'srcT': 'sqlstatement',
#    'desT': 'createstatement',
#    'path': 'name↑-expr-call↓name↓name↓'},
#   {'srcT': 'dbconnection',
#    'desT': 'sqlstatement',
#    'path': 'name↑name↑call↑-expr-name↓'},
#   {'srcT': 'dbconnection',
#    'desT': 'createstatement',
#    'path': 'name↑-name-name↓'},
#   {'srcT': 'createstatement',
#    'desT': 'sqlstatement',
#    'path': 'name↑name↑call↑-expr-name↓'},
#   {'srcT': 'createstatement',
#    'desT': 'dbconnection',
#    'path': 'name↑-name-name↓'},
#   {'srcT': 'int', 'desT': 'rowcount', 'path': 'name↑type↑-decl-name↓'},
#   {'srcT': 'rowcount', 'desT': 'int', 'path': 'name↑-decl-type↓name↓'},
#   {'srcT': 'sqlstatement',
#    'desT': 'executeupdate',
#    'path': 'name↑-name-name↓'},
#   {'srcT': 'executeupdate',
#    'desT': 'sqlstatement',
#    'path': 'name↑-name-name↓'},
#   {'srcT': 'insertintousersstatusvaluesupdatedwherename',
#    'desT': 'data',
#    'path': 'literal↑-expr-name↓'},
#   {'srcT': 'data',
#    'desT': 'insertintousersstatusvaluesupdatedwherename',
#    'path': 'name↑-expr-literal↓'},
#   {'srcT': 'io', 'desT': 'writeline', 'path': 'name↑-name-name↓'},
#   {'srcT': 'writeline', 'desT': 'io', 'path': 'name↑-name-name↓'},
#   {'srcT': 'updated', 'desT': 'rowcount', 'path': 'literal↑-expr-name↓'},
#   {'srcT': 'updated',
#    'desT': 'rowssuccessfully',
#    'path': 'literal↑-expr-literal↓'},
#   {'srcT': 'rowcount', 'desT': 'updated', 'path': 'name↑-expr-literal↓'},
#   {'srcT': 'rowcount',
#    'desT': 'rowssuccessfully',
#    'path': 'name↑-expr-literal↓'},
#   {'srcT': 'rowssuccessfully',
#    'desT': 'updated',
#    'path': 'literal↑-expr-literal↓'},
#   {'srcT': 'rowssuccessfully',
#    'desT': 'rowcount',
#    'path': 'literal↑-expr-name↓'},
#   {'srcT': 'catch',
#    'desT': 'exceptsql',
#    'path': '-catch-parameter_list↓parameter↓decl↓name↓'},
#   {'srcT': 'catch', 'desT': 'finally', 'path': 'catch↑-try-finally↓'},
#   {'srcT': 'sqlexception',
#    'desT': 'exceptsql',
#    'path': 'name↑type↑-decl-name↓'},
#   {'srcT': 'exceptsql',
#    'desT': 'catch',
#    'path': 'name↑decl↑parameter↑parameter_list↑-catch-'},
#   {'srcT': 'exceptsql',
#    'desT': 'sqlexception',
#    'path': 'name↑-decl-type↓name↓'},
#   {'srcT': 'io', 'desT': 'logger', 'path': 'name↑-name-name↓'},
#   {'srcT': 'io', 'desT': 'log', 'path': 'name↑-name-name↓'},
#   {'srcT': 'logger', 'desT': 'io', 'path': 'name↑-name-name↓'},
#   {'srcT': 'logger', 'desT': 'log', 'path': 'name↑-name-name↓'},
#   {'srcT': 'log', 'desT': 'io', 'path': 'name↑-name-name↓'},
#   {'srcT': 'log', 'desT': 'logger', 'path': 'name↑-name-name↓'},
#   {'srcT': 'level', 'desT': 'warning', 'path': 'name↑-name-name↓'},
#   {'srcT': 'warning', 'desT': 'level', 'path': 'name↑-name-name↓'},
#   {'srcT': 'finally', 'desT': 'catch', 'path': 'finally↑-try-catch↓'},
#   {'srcT': 'finally',
#    'desT': 'try',
#    'path': '-finally-block↓block_content↓try↓'},
#   {'srcT': 'finally',
#    'desT': 'catch',
#    'path': '-finally-block↓block_content↓try↓catch↓'},
#   {'srcT': 'try',
#    'desT': 'finally',
#    'path': 'try↑block_content↑block↑-finally-'},
#   {'srcT': 'try',
#    'desT': 'if',
#    'path': '-try-block↓block_content↓if_stmt↓if↓'},
#   {'srcT': 'try', 'desT': 'catch', 'path': '-try-catch↓'},
#   {'srcT': 'if',
#    'desT': 'try',
#    'path': 'if↑if_stmt↑block_content↑block↑-try-'},
#   {'srcT': 'if', 'desT': 'sqlstatement', 'path': '-if-condition↓expr↓name↓'},
#   {'srcT': 'if', 'desT': 'null', 'path': '-if-condition↓expr↓literal↓'},
#   {'srcT': 'sqlstatement', 'desT': 'if', 'path': 'name↑expr↑condition↑-if-'},
#   {'srcT': 'sqlstatement', 'desT': 'null', 'path': 'name↑-expr-literal↓'},
#   {'srcT': 'null', 'desT': 'if', 'path': 'literal↑expr↑condition↑-if-'},
#   {'srcT': 'null', 'desT': 'sqlstatement', 'path': 'literal↑-expr-name↓'},
#   {'srcT': 'sqlstatement', 'desT': 'close', 'path': 'name↑-name-name↓'},
#   {'srcT': 'close', 'desT': 'sqlstatement', 'path': 'name↑-name-name↓'},
#   {'srcT': 'catch',
#    'desT': 'finally',
#    'path': 'catch↑try↑block_content↑block↑-finally-'},
#   {'srcT': 'catch', 'desT': 'try', 'path': 'catch↑-try-'},
#   {'srcT': 'catch',
#    'desT': 'exceptsql',
#    'path': '-catch-parameter_list↓parameter↓decl↓name↓'},
#   {'srcT': 'catch', 'desT': 'try', 'path': 'catch↑try↑-block_content-try↓'},
#   {'srcT': 'sqlexception',
#    'desT': 'exceptsql',
#    'path': 'name↑type↑-decl-name↓'},
#   {'srcT': 'exceptsql',
#    'desT': 'catch',
#    'path': 'name↑decl↑parameter↑parameter_list↑-catch-'},
#   {'srcT': 'exceptsql',
#    'desT': 'sqlexception',
#    'path': 'name↑-decl-type↓name↓'},
#   {'srcT': 'io', 'desT': 'logger', 'path': 'name↑-name-name↓'},
#   {'srcT': 'io', 'desT': 'log', 'path': 'name↑-name-name↓'},
#   {'srcT': 'logger', 'desT': 'io', 'path': 'name↑-name-name↓'},
#   {'srcT': 'logger', 'desT': 'log', 'path': 'name↑-name-name↓'},
#   {'srcT': 'log', 'desT': 'io', 'path': 'name↑-name-name↓'},
#   {'srcT': 'log', 'desT': 'logger', 'path': 'name↑-name-name↓'},
#   {'srcT': 'level', 'desT': 'warning', 'path': 'name↑-name-name↓'},
#   {'srcT': 'warning', 'desT': 'level', 'path': 'name↑-name-name↓'},
#   {'srcT': 'try', 'desT': 'catch', 'path': 'try↑-block_content-try↓catch↓'},
#   {'srcT': 'try',
#    'desT': 'if',
#    'path': '-try-block↓block_content↓if_stmt↓if↓'},
#   {'srcT': 'try', 'desT': 'catch', 'path': '-try-catch↓'},
#   {'srcT': 'if',
#    'desT': 'try',
#    'path': 'if↑if_stmt↑block_content↑block↑-try-'},
#   {'srcT': 'if', 'desT': 'dbconnection', 'path': '-if-condition↓expr↓name↓'},
#   {'srcT': 'if', 'desT': 'null', 'path': '-if-condition↓expr↓literal↓'},
#   {'srcT': 'dbconnection', 'desT': 'if', 'path': 'name↑expr↑condition↑-if-'},
#   {'srcT': 'dbconnection', 'desT': 'null', 'path': 'name↑-expr-literal↓'},
#   {'srcT': 'null', 'desT': 'if', 'path': 'literal↑expr↑condition↑-if-'},
#   {'srcT': 'null', 'desT': 'dbconnection', 'path': 'literal↑-expr-name↓'},
#   {'srcT': 'dbconnection', 'desT': 'close', 'path': 'name↑-name-name↓'},
#   {'srcT': 'close', 'desT': 'dbconnection', 'path': 'name↑-name-name↓'},
#   {'srcT': 'catch', 'desT': 'try', 'path': 'catch↑-try-'},
#   {'srcT': 'catch',
#    'desT': 'exceptsql',
#    'path': '-catch-parameter_list↓parameter↓decl↓name↓'},
#   {'srcT': 'sqlexception',
#    'desT': 'exceptsql',
#    'path': 'name↑type↑-decl-name↓'},
#   {'srcT': 'exceptsql',
#    'desT': 'catch',
#    'path': 'name↑decl↑parameter↑parameter_list↑-catch-'},
#   {'srcT': 'exceptsql',
#    'desT': 'sqlexception',
#    'path': 'name↑-decl-type↓name↓'},
#   {'srcT': 'io', 'desT': 'logger', 'path': 'name↑-name-name↓'},
#   {'srcT': 'io', 'desT': 'log', 'path': 'name↑-name-name↓'},
#   {'srcT': 'logger', 'desT': 'io', 'path': 'name↑-name-name↓'},
#   {'srcT': 'logger', 'desT': 'log', 'path': 'name↑-name-name↓'},
#   {'srcT': 'log', 'desT': 'io', 'path': 'name↑-name-name↓'},
#   {'srcT': 'log', 'desT': 'logger', 'path': 'name↑-name-name↓'},
#   {'srcT': 'level', 'desT': 'warning', 'path': 'name↑-name-name↓'},
#   {'srcT': 'warning', 'desT': 'level', 'path': 'name↑-name-name↓'}],
#  [{'srcT': 'private', 'desT': 'void', 'path': '-***-'},
#   {'srcT': 'private', 'desT': 'good1', 'path': '-***-'},
#   {'srcT': 'void', 'desT': 'private', 'path': '-***-'},
#   {'srcT': 'void', 'desT': 'good1', 'path': 'name↑type↑-function-name↓'},
#   {'srcT': 'good1', 'desT': 'private', 'path': '-***-'},
#   {'srcT': 'good1', 'desT': 'void', 'path': 'name↑-function-type↓name↓'},
#   {'srcT': 'io', 'desT': 'writeline', 'path': 'name↑-name-name↓'},
#   {'srcT': 'writeline', 'desT': 'io', 'path': 'name↑-name-name↓'}],
#  [{'srcT': 'public', 'desT': 'void', 'path': '-***-'},
#   {'srcT': 'public', 'desT': 'good', 'path': '-***-'},
#   {'srcT': 'void', 'desT': 'public', 'path': '-***-'},
#   {'srcT': 'void', 'desT': 'good', 'path': 'name↑type↑-function-name↓'},
#   {'srcT': 'good', 'desT': 'public', 'path': '-***-'},
#   {'srcT': 'good', 'desT': 'void', 'path': 'name↑-function-type↓name↓'}],
#  [{'srcT': 'public', 'desT': 'static', 'path': '-***-'},
#   {'srcT': 'public', 'desT': 'void', 'path': '-***-'},
#   {'srcT': 'public', 'desT': 'main', 'path': '-***-'},
#   {'srcT': 'public', 'desT': 'throws', 'path': '-***-'},
#   {'srcT': 'static', 'desT': 'public', 'path': '-***-'},
#   {'srcT': 'static', 'desT': 'void', 'path': '-***-'},
#   {'srcT': 'static', 'desT': 'main', 'path': '-***-'},
#   {'srcT': 'static', 'desT': 'throws', 'path': '-***-'},
#   {'srcT': 'void', 'desT': 'public', 'path': '-***-'},
#   {'srcT': 'void', 'desT': 'static', 'path': '-***-'},
#   {'srcT': 'void', 'desT': 'main', 'path': 'name↑type↑-function-name↓'},
#   {'srcT': 'void', 'desT': 'throws', 'path': 'name↑type↑-function-throws↓'},
#   {'srcT': 'main', 'desT': 'public', 'path': '-***-'},
#   {'srcT': 'main', 'desT': 'static', 'path': '-***-'},
#   {'srcT': 'main', 'desT': 'void', 'path': 'name↑-function-type↓name↓'},
#   {'srcT': 'main', 'desT': 'throws', 'path': 'name↑-function-throws↓'},
#   {'srcT': 'string', 'desT': 'args', 'path': 'name↑name↑type↑-decl-name↓'},
#   {'srcT': 'args', 'desT': 'string', 'path': 'name↑-decl-type↓name↓name↓'},
#   {'srcT': 'throws', 'desT': 'public', 'path': '-***-'},
#   {'srcT': 'throws', 'desT': 'static', 'path': '-***-'},
#   {'srcT': 'throws', 'desT': 'void', 'path': 'throws↑-function-type↓name↓'},
#   {'srcT': 'throws', 'desT': 'main', 'path': 'throws↑-function-name↓'},
#   {'srcT': 'throws',
#    'desT': 'classnotfoundexception',
#    'path': '-throws-argument↓expr↓name↓'},
#   {'srcT': 'throws',
#    'desT': 'instantiationexception',
#    'path': '-throws-argument↓expr↓name↓'},
#   {'srcT': 'throws',
#    'desT': 'illegalaccessexception',
#    'path': '-throws-argument↓expr↓name↓'},
#   {'srcT': 'classnotfoundexception',
#    'desT': 'throws',
#    'path': 'name↑expr↑argument↑-throws-'},
#   {'srcT': 'instantiationexception',
#    'desT': 'throws',
#    'path': 'name↑expr↑argument↑-throws-'},
#   {'srcT': 'illegalaccessexception',
#    'desT': 'throws',
#    'path': 'name↑expr↑argument↑-throws-'}]]

# %%
# remove all deps which contain 'specifier' node in the path
rs_obj = get_rs_obj_from_filtered_data_list('juliet', ['specifier'])
# Out:
# 100%|██████████| 118/118 [00:00<00:00, 4114.80it/s]

# %%
def outputData(data_set_name, rs_obj):
    out_dir = os.path.join('srcxml', f'{data_set_name}_out')
    if not os.path.exists(out_dir):
        os.mkdir(out_dir)
    
    with open(os.path.join(out_dir, f'voc2id.txt'), 'w') as f:
        for _tk, _id in rs_obj['token_id_map'].items():
            f.write(f'{_tk}\t{_id}\r\n')
            
    with open(os.path.join(out_dir, f'id2freq.txt'), 'w') as f:
        for _tk, _feq in rs_obj['token_frequecy_map'].items():
            _id = rs_obj['token_id_map'][_tk]
            f.write(f'{_id}\t{_feq}\r\n')

    with open(os.path.join(out_dir, f'de2id.txt'), 'w') as f:
        for _dep, _id in rs_obj['dep_id_map'].items():
            f.write(f'{_dep}\t{_id}\r\n')
            
    with open(os.path.join(out_dir, f'de2freq.txt'), 'w') as f:
        for _dep, _feq in rs_obj['dep_frequecy_map'].items():
            f.write(f'{_feq}\t\t{_dep}\r\n')
            
    with open(os.path.join(out_dir, f'data.txt'), 'w') as f:
        for sentence_triples in rs_obj['sentence_triples']:
            tk_set = set([])
            dep_path_list = []
            for triple in sentence_triples:
                srcT_id, desT_id, dep_path_id = triple
                tk_set.add(srcT_id)
                tk_set.add(desT_id)
                
                dep_path_list.append((srcT_id, desT_id, dep_path_id))
                
            tk_id_list = list(tk_set)
            
            # dep_path_list = [f"{sdd[0]}|{sdd[1]}|{sdd[2]}" for sdd in dep_path_list]
            dep_path_list = [f"{tk_id_list.index(sdd[0])}|{tk_id_list.index(sdd[1])}|{sdd[2]}" for sdd in dep_path_list]
            
            f.write(f'{len(tk_id_list)} ')
            f.write(f'{len(dep_path_list)} ')
            f.write(' '.join([str(_id) for _id in tk_id_list]))
            f.write(' ')
            f.write(' '.join(dep_path_list))
            f.write('\r\n')

# %%
outputData('juliet_new', rs_obj)
